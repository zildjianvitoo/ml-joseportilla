# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Coding\\python-projects\\ml-jose-portilla\\jose\\03-Pandas\\mpg.csv")

df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.groupby(["cylinders","model_year"]).mean(numeric_only=True)
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 3         72          19.000000     70.000000  2330.000000     13.500000
#           73          18.000000     70.000000  2124.000000     13.500000
#           77          21.500000     80.000000  2720.000000     13.500000
#           80          23.700000     70.000000  2420.000000     12.500000
# 4         70          25.285714    107.000000  2292.571429     16.000000
#           71          27.461538    101.846154  2056.384615     16.961538
#           72          23.428571    111.535714  2382.642857     17.214286
#           73          22.727273    109.272727  2338.090909     17.136364
#           74          27.800000     96.533333  2151.466667     16.400000
#           75          25.250000    114.833333  2489.250000     15.833333
#           76          26.766667    106.333333  2306.600000     16.866667
# ...

# %%
np.round(df.groupby(["cylinders","model_year"]).describe())
# Out:
#                        mpg                                            \
#                      count  mean   std   min   25%   50%   75%   max
# cylinders model_year
# 3         72           1.0  19.0   NaN  19.0  19.0  19.0  19.0  19.0
#           73           1.0  18.0   NaN  18.0  18.0  18.0  18.0  18.0
#           77           1.0  22.0   NaN  22.0  22.0  22.0  22.0  22.0
#           80           1.0  24.0   NaN  24.0  24.0  24.0  24.0  24.0
# 4         70           7.0  25.0   1.0  24.0  24.0  25.0  26.0  27.0
#           71          13.0  27.0   4.0  22.0  25.0  27.0  30.0  35.0
#           72          14.0  23.0   3.0  18.0  21.0  23.0  26.0  28.0
#           73          11.0  23.0   3.0  19.0  20.0  22.0  25.0  29.0
#           74          15.0  28.0   3.0  24.0  26.0  26.0  31.0  32.0
#           75          12.0  25.0   3.0  22.0  23.0  24.0  26.0  33.0
#           76          15.0  27.0   4.0  19.0  25.0  27.0  29.0  33.0
# ...

# %%
year_cyl_mean = df.groupby(["model_year","cylinders"]).mean(numeric_only=True)
year_cyl_mean.loc[[70,82]]
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 82         4          32.071429    118.571429  2402.321429     16.703571
#            6          28.333333    225.000000  2931.666667     16.033333
#
#                         origin
# model_year cylinders
# 70         4          2.285714
#            6          1.000000
#            8          1.000000
# 82         4          1.714286
#            6          1.000000

# %%
year_cyl_mean.index
# Out:
# MultiIndex([(70, 4),
#             (70, 6),
#             (70, 8),
#             (71, 4),
#             (71, 6),
#             (71, 8),
#             (72, 3),
#             (72, 4),
#             (72, 8),
#             (73, 3),
#             (73, 4),
#             (73, 6),
#             (73, 8),
#             (74, 4),
#             (74, 6),
#             (74, 8),
#             (75, 4),
#             (75, 6),
#             (75, 8),
#             (76, 4),
#             (76, 6),
#             (76, 8),
#             (77, 3),
#             (77, 4),
#             (77, 6),
#             (77, 8),
#             (78, 4),
#             (78, 5),
#             (78, 6),
#             (78, 8),
#             (79, 4),
#             (79, 5),
#             (79, 6),
#             (79, 8),
#             (80, 3),
#             (80, 4),
#             (80, 5),
#             (80, 6),
#             (81, 4),
#             (81, 6),
#             (81, 8),
#             (82, 4),
#             (82, 6)],
# ...

# %%
year_cyl_mean.xs(key=3,level="cylinders")
# Out:
#              mpg  displacement  weight  acceleration  origin
# model_year
# 72          19.0          70.0  2330.0          13.5     3.0
# 73          18.0          70.0  2124.0          13.5     3.0
# 77          21.5          80.0  2720.0          13.5     3.0
# 80          23.7          70.0  2420.0          12.5     3.0

# %%
filtered_columns = (df["cylinders"].isin([6,8])) & (df["model_year"].isin([70,75,82]))

df[filtered_columns].groupby(["cylinders", "model_year"]).mean(numeric_only=True)
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 6         70          20.500000    199.000000  2710.500000     15.500000
#           75          17.583333    233.750000  3398.333333     17.708333
#           82          28.333333    225.000000  2931.666667     16.033333
# 8         70          14.111111    367.555556  3940.055556     11.194444
#           75          15.666667    330.500000  4108.833333     13.166667
#
#                       origin
# cylinders model_year
# 6         70             1.0
#           75             1.0
#           82             1.0
# 8         70             1.0
#           75             1.0

# %%
year_cyl_mean.swaplevel().groupby(["cylinders","model_year"]).mean()
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 3         72          19.000000     70.000000  2330.000000     13.500000
#           73          18.000000     70.000000  2124.000000     13.500000
#           77          21.500000     80.000000  2720.000000     13.500000
#           80          23.700000     70.000000  2420.000000     12.500000
# 4         70          25.285714    107.000000  2292.571429     16.000000
#           71          27.461538    101.846154  2056.384615     16.961538
#           72          23.428571    111.535714  2382.642857     17.214286
#           73          22.727273    109.272727  2338.090909     17.136364
#           74          27.800000     96.533333  2151.466667     16.400000
#           75          25.250000    114.833333  2489.250000     15.833333
#           76          26.766667    106.333333  2306.600000     16.866667
# ...

# %%
year_cyl_mean.sort_index(level="model_year",ascending=False)
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 82         6          28.333333    225.000000  2931.666667     16.033333
#            4          32.071429    118.571429  2402.321429     16.703571
# 81         8          26.600000    350.000000  3725.000000     19.000000
#            6          23.428571    184.000000  3093.571429     15.442857
#            4          32.814286    108.857143  2275.476190     16.466667
# 80         6          25.900000    196.500000  3145.500000     15.050000
#            5          36.400000    121.000000  2950.000000     19.900000
#            4          34.612000    111.000000  2360.080000     17.144000
#            3          23.700000     70.000000  2420.000000     12.500000
# 79         8          18.630000    321.400000  3862.900000     15.400000
#            6          22.950000    205.666667  3025.833333     15.433333
# ...

# %%
numeric_column = df.select_dtypes(np.number)


numeric_column.agg({"mpg": ["mean"],"acceleration": ["max"]})
# Out:
#             mpg  acceleration
# mean  23.514573           NaN
# max         NaN          24.8
