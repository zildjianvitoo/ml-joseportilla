# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv(
    "C:\\Coding\\python-projects\\ml-jose-portilla\\jose\\05-Seaborn\\dm_office_sales.csv"
)
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(
    data=df,
    x="salary",
    y="sales",
    hue="level of education",
    style="level of education",
)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(10,4))

sns.scatterplot(
    x="salary", y="sales", data=df, hue="level of education", style="level of education",s=150
)

plt.savefig("59-scatter.png")
